# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('canada_per_capita_income.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# reg=linear_model.LinearRegression()
# reg.fit(df[['year']],df['per capita income (US$)'])

# %%
# %matplotlib inline
# plt.xlabel('year')
# plt.ylabel('per capita income (US$)')
# plt.scatter(df.year,df['per capita income (US$)'],color='red',marker='+')
# plt.plot(df.year,reg.predict(df[['year']]),df['per capita income (US$)'],color='red')

# %%
# df=pd.read_csv(r'C:\Users\Sahil\Desktop\Desktop\ml\py\ML\1_linear_reg\homeprices.csv')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year,df['per capita income (US$)'],color='red',marker='+')
plt.plot(df.year,reg.predict(df[['year']]),color='blue')
plt.scatter(2020,reg.predict([[2020]]),color='green')
plt.scatter(2021,reg.predict([[2021]]),color='green')
# Out:
# c:\Users\Sahil\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\Sahil\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg.predict([[2020]])
# Out:
# c:\Users\Sahil\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
